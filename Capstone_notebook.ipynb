# %% [markdown]
# <h1>My Capstone Project</h1>
#     This Notebook present the code process of my capstone project

# %% [markdown]
# <h3>Importing our essential libraries  the project</h3>

# %%
import pandas as pd 
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
